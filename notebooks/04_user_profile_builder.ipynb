# %%
import pandas as pd

from src.ml.ranking_model import load_training_data
from src.llm.user_profile_builder import build_user_profile

# %%
df_ml = load_training_data()
df_ml.head()

# %%
examples = df_ml.sample(3, random_state=4)
examples

# %%
for idx, row in examples.iterrows():
    print("=== CLIENT", row["client_id"], "===\n")
    print(build_user_profile(row))
    print("\n" + "-"*80 + "\n")

# %%
import pandas as pd

from src.ml.ranking_model import load_training_data, train_ranking_model

# %%
df_ml = load_training_data()
df_ml.head()
# Out:
# 2025-12-06 21:19:39 | INFO | src.ml.ranking_model:load_training_data - Loaded ML training dataset: %s, shape=%s
#    client_id  treatment  offer_id treatment_date     offer_type  \
# 0      17850          1         0     2024-04-12    discount_10
# 1      13047          1         2     2024-03-12  free_delivery
# 2      12583          1         1     2024-01-21    discount_20
# 3      12583          1         0     2024-04-12    discount_10
# 4      12583          1         0     2024-05-01    discount_10
#
#   offer_category  cost  offer_AOV channel  conversion  ...  \
# 0     category_0  2.09      18.15     app           0  ...
# 1     category_8  5.65      18.82     app           0  ...
# 2     category_8  5.13      29.48     web           0  ...
# 3     category_8  7.16      29.48     app           1  ...
# 4     category_8  1.49      29.48     web           0  ...
#
#    category_affinity_top1  is_mobile_user  city_tier  email_open_rate_30d  \
# ...

# %%
model, split = train_ranking_model(df_ml)

X_test = split.X_test
y_test = split.y_test
feature_cols = split.feature_cols
cat_feature_indices = split.cat_feature_indices
# Out:
# 2025-12-06 21:19:39 | INFO | src.ml.ranking_model:_prepare_features - Train/test split: train=%d, test=%d, features=%d (cat=%d)
# 2025-12-06 21:19:39 | INFO | src.ml.ranking_model:train_ranking_model - Start CatBoost training...
# 0:	test: 0.7086767	best: 0.7086767 (0)	total: 67.6ms	remaining: 20.2s
# 50:	test: 0.7340019	best: 0.7343727 (47)	total: 391ms	remaining: 1.91s
# 100:	test: 0.7357935	best: 0.7357935 (100)	total: 732ms	remaining: 1.44s
# 150:	test: 0.7334891	best: 0.7364199 (108)	total: 1.08s	remaining: 1.07s
# 200:	test: 0.7300076	best: 0.7364199 (108)	total: 1.44s	remaining: 709ms
# 250:	test: 0.7276092	best: 0.7364199 (108)	total: 1.78s	remaining: 348ms
# 299:	test: 0.7230769	best: 0.7364199 (108)	total: 2.13s	remaining: 0us
#
# bestTest = 0.7364199079
# bestIteration = 108
#
# Shrink model to first 109 iterations.
# 2025-12-06 21:19:42 | INFO | src.ml.ranking_model:train_ranking_model - Training finished.
# ...
